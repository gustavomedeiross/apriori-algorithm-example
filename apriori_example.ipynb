# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mendes13/apriori-algorithm-example/main/groceries.csv")
df = df.replace(np.nan, 0).drop(columns=["Item(s)"])
df.head(10)
# Out:
#              Item 1               Item 2  ... Item 31 Item 32
# 0      citrus fruit  semi-finished bread  ...       0       0
# 1    tropical fruit               yogurt  ...       0       0
# 2        whole milk                    0  ...       0       0
# 3         pip fruit               yogurt  ...       0       0
# 4  other vegetables           whole milk  ...       0       0
# 5        whole milk               butter  ...       0       0
# 6        rolls/buns                    0  ...       0       0
# 7  other vegetables             UHT-milk  ...       0       0
# 8     potted plants                    0  ...       0       0
# 9        whole milk              cereals  ...       0       0
#
# [10 rows x 32 columns]

# %%
def remove_zeros(array):
  return list(filter(lambda item: item != 0, array))

# %%
transactions = []

for i, row in df.iterrows():
  items_bought = row.values.tolist()
  transactions.append(remove_zeros(items_bought))

transactions[0]
# Out:
# ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups']

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_array, columns=te.columns_)

df.head(10)
# Out:
#    Instant food products  UHT-milk  ...  yogurt  zwieback
# 0                  False     False  ...   False     False
# 1                  False     False  ...    True     False
# 2                  False     False  ...   False     False
# 3                  False     False  ...    True     False
# 4                  False     False  ...   False     False
# 5                  False     False  ...    True     False
# 6                  False     False  ...   False     False
# 7                  False      True  ...   False     False
# 8                  False     False  ...   False     False
# 9                  False     False  ...   False     False
#
# [10 rows x 169 columns]

# %%
 from mlxtend.frequent_patterns import apriori

 frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

 frequent_itemsets.sort_values(by=['support'], ascending=False)
# Out:
#       support                    itemsets
# 86   0.255516                (whole milk)
# 55   0.193493          (other vegetables)
# 66   0.183935                (rolls/buns)
# 75   0.174377                      (soda)
# 87   0.139502                    (yogurt)
# ..        ...                         ...
# 178  0.010066      (frankfurter, sausage)
# 306  0.010066  (yogurt, curd, whole milk)
# 160  0.010066          (curd, rolls/buns)
# 212  0.010066   (tropical fruit, napkins)
# 199  0.010066   (hard cheese, whole milk)
#
# [333 rows x 2 columns]

# %%
 from mlxtend.frequent_patterns import association_rules

 rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.5)

 rules.sort_values(by=['lift'], ascending=False).drop(columns=['antecedent support', 'consequent support', 'leverage', 'conviction'])
# Out:
#                                antecedents  ...      lift
# 1          (citrus fruit, root vegetables)  ...  3.029608
# 6        (root vegetables, tropical fruit)  ...  3.020999
# 5            (root vegetables, rolls/buns)  ...  2.594890
# 7                (yogurt, root vegetables)  ...  2.584078
# 2                           (yogurt, curd)  ...  2.279125
# 0               (butter, other vegetables)  ...  2.244885
# 11       (root vegetables, tropical fruit)  ...  2.230969
# 12               (yogurt, root vegetables)  ...  2.203354
# 3        (other vegetables, domestic eggs)  ...  2.162336
# 14            (yogurt, whipped/sour cream)  ...  2.052747
# 10           (root vegetables, rolls/buns)  ...  2.046888
# 4            (other vegetables, pip fruit)  ...  2.025351
# 13                (yogurt, tropical fruit)  ...  2.024770
# 9               (yogurt, other vegetables)  ...  2.007235
# 8   (whipped/sour cream, other vegetables)  ...  1.984385
#
# [15 rows x 5 columns]

# %%
 r = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.00)
 r = r.drop(columns=['antecedent support', 'consequent support', 'leverage', 'conviction'])
 r.describe()
# Out:
#           support  confidence        lift
# count  618.000000  618.000000  618.000000
# mean     0.016528    0.195836    1.726936
# std      0.008382    0.126470    0.496699
# min      0.010066    0.039395    0.789888
# 25%      0.011286    0.099470    1.368615
# 50%      0.013625    0.159303    1.643695
# 75%      0.018709    0.261035    2.024770
# max      0.074835    0.586207    3.372304
